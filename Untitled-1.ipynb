# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
im = Image.open('/home/somahansel/developer/data/DIC-C2DH-HeLa/01_GT/SEG/man_seg067.tif')

# %%
im_np = np.array(im)
np.bincount(im_np.flatten())
# Out:
# array([239523,  11090,   4546,   6985])

# %%
plt.imshow(im_np*25)
plt.show()
